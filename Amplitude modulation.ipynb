# %% [markdown]
# # <div align="center"> Name - Sharika Anjum Mondal </div>
# # <div align="center"> Enrolment no. - A91005118016 </div>
# # <div align="center"> B.Tech ECE </div>
# # <div align="center"> 6th semester </div>
# # <div align="center"> Telecommunication Switching </div>
# # <div align="center"> Lab Records </div>

# %% [markdown]
# # <div align="center"> ------------------------------------------------------------ </div>

# %% [markdown]
# # <div align="center"><u>Experiment </u></div>

# %% [markdown]
# **<u>AIM :</u> Amplitude Modulation using Python.**

# %% [markdown]
# **<u>THEORY :</u>** *In communication labs in our colleges we all generate amplitudemodulated signals using CROs. But the same can be performed byusing Python and few of its additional libraries and the endresult can be equally dope.At first let’s revise the formulas needed to generate amplitudemodulated signal.*
#
# m(t) = Am cos wmt
#
# c(t) = Ac cos wct
#
# AM(t) = [Ac + m(t)]cos wct

# %% [markdown]
# **<u>CODE with OUTPUT :</u>**

# %% [markdown]
# Importing the required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Then   we   have   to   take   carrier   amplitude,   carrier   frequency,message   amplitude,   message   frequency   and   modulation   index   asinputs.

# %%
Ac = float(input('Enter the carrier signal Amplitude: '))
fc = float(input('Enter the carrier signal frequency: '))
Am = float(input('Enter the message signal Amplitude: '))
fm = float(input('Enter the message signal frequency: '))
m = float(input('Enter the modulation index: '))
# Out:
# Enter the carrier signal Amplitude: 50
# Enter the carrier signal frequency: 15
# Enter the message signal Amplitude: 25
# Enter the message signal frequency: 10
# Enter the modulation index: 0.5

# %% [markdown]
# The built-in input function in python returns string value. So wehave to convert them to integer or float. Now float is preferred because amplitude or frequency can be in decimal too.
#
# The time function in analog communication is continuous function.To replicate its behavior we will use  linspace  function whichwill   provide   large   number   of   discrete   points   which   will   actalmost similar to continuous function. The linspace function willgenerate evenly spaced numbers within a given interval.
# The first argument of linspace is starting point, second argument is endingpoint and third argument is number of breakpoints between the given interval.

# %%
t = np.linspace(0,1,1000)

# %% [markdown]
# Now we will create our carrier, modulator(message), and productfunction. Here we will use sin , cos and pi from numpy.

# %%
carrier = Ac*np.cos(2*np.pi*fc*t)
message = Am*np.cos(2*np.pi*fm*t)
product = Ac*(1+m*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)

# %% [markdown]
# Here comes the plotting part. We will utilize matplotlib libraryfunctions.
#
# The subplot function creates more than one plot in thecanvas.
#
# The  plot  function   plots   the   given   function.   In  plotfunction we can pass color names or their acronyms to plot thegraph in any color we wish. The ‘g’ , ‘r’ stands for green andred respectively. The xlabel and ylabel prints the x-axis and y-axis variable names. And the title function prints the title ofthe over all plot.

# %%
plt.subplot(3,1,1)
plt.title('Amplitude Modulation')
plt.plot(message, 'g')
plt.ylabel('Amplitude')
plt.xlabel('Message signal')

plt.subplot(3,1,2)
plt.plot(carrier, 'r')
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')

plt.subplot(3,1,3)
plt.plot(product, 'b')
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')
# Out:
# Text(0.5, 0, 'Carrier signal')

# %% [markdown]
# Now all the waves together.

# %%
plt.plot(message, 'g')
plt.plot(carrier, 'r')
plt.plot(product, 'b')
plt.title('Amplitude Modulation')
plt.ylabel('Amplitude')
plt.grid(True)
plt.legend(["message signal","carrier signal","AM signal"],loc = 'upper right')

# %% [markdown]
# **<u>CONCLUSION :</u>** *Amplitude modulation using python is performed and studied.*

# %% [markdown]
# # <div align="center"> ------------------------------------------------------------ </div>
